# %% [markdown]
# <a href="https://colab.research.google.com/github/kakakafafafa888/Adipose_Ghost_Analysis/blob/main/00enviromen_prepare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title ⚓️ 启动协议：挂载云端与环境初始化 (Run This First!)
import os
import sys
import warnings
from google.colab import drive

# ==========================================
# 1. 建立云端连接 (The Digital Umbilical Cord)
# ==========================================
if not os.path.exists('/content/drive'):
    print("🔌 正在连接 Google Drive...")
    drive.mount('/content/drive')
else:
    print("✅ Google Drive 已连接。")

# ==========================================
# 2. 锁定项目基地 (Navigation)
# ==========================================
# 这是我们所有数据的根目录，改这里牵一发而动全身
PROJECT_ROOT = '/content/drive/MyDrive/Project_Adipose_Ghost'

# 检查目录是否存在，不存在就报错，防止你写错路径瞎跑
if os.path.exists(PROJECT_ROOT):
    os.chdir(PROJECT_ROOT)
    print(f"📂 工作目录已切换至: {os.getcwd()}")

    # 打印当前目录结构，确认没走错门
    print("   └─ 当前内容:", [x for x in os.listdir('.') if not x.startswith('.')])
else:
    print(f"❌ 致命错误: 找不到项目目录 {PROJECT_ROOT}")
    print("   请检查 Google Drive 文件夹名称是否被你改乱了！")

# ==========================================
# 3. 加载基础工具箱 (The Toolkit)
# ==========================================
# 预加载这些库，后面的代码就能直接用 sc.read... 而不用重新 import
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 设置绘图风格 (Nature 风格)
sc.settings.set_figure_params(dpi=100, frameon=False, vector_friendly=True, fontsize=12)
sc.settings.verbosity = 3  # 输出提示信息

# 忽略烦人的警告
warnings.filterwarnings('ignore')

print("\n🚀 猎户座系统启动完毕。随时可以开始分析。")
